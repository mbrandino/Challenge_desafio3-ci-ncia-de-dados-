# %% [markdown]
# <a href="https://colab.research.google.com/github/mbrandino/Challenge_desafio3-ci-ncia-de-dados-/blob/main/Challenge_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_csv('/content/Telecom_X_normalizado.csv', sep = ';')
dados.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  1423-BMPBQ    No  Female              0     Yes        Yes       1
# 1  3807-XHCJH    No  Female              0     Yes        Yes       1
# 2  4877-EVATK   Yes    Male              0      No         No       1
# 3  7698-YFGEZ    No    Male              0      No         No       1
# 4  6770-XUAGN   Yes  Female              0     Yes        Yes       1
#
#   PhoneService MultipleLines InternetService  ...         OnlineBackup  \
# 0          Yes            No              No  ...  No internet service
# 1          Yes            No              No  ...  No internet service
# 2          Yes            No              No  ...  No internet service
# 3          Yes            No              No  ...  No internet service
# 4          Yes            No              No  ...  No internet service
#
#       DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
dados.head()
# Out:
#   customerID;Churn;gender;SeniorCitizen;Partner;Dependents;tenure;PhoneService;MultipleLines;InternetService;OnlineSecurity;OnlineBackup;DeviceProtection;TechSupport;StreamingTV;StreamingMovies;Contract;PaperlessBilling;PaymentMethod;Charges  \
# 0  1423-BMPBQ;No;Female;0;Yes;Yes;1;Yes;No;No;No ...
# 1  3807-XHCJH;No;Female;0;Yes;Yes;1;Yes;No;No;No ...
# 2  4877-EVATK;Yes;Male;0;No;No;1;Yes;No;No;No int...
# 3  7698-YFGEZ;No;Male;0;No;No;1;Yes;No;No;No inte...
# 4  6770-XUAGN;Yes;Female;0;Yes;Yes;1;Yes;No;No;No...
#
#   Monthly;Charges  Total
# 0           00;19      0
# 1           00;20      0
# 2           00;20      0
# 3           00;20      0
# 4           00;21      0
